# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from matplotlib import cm

# %%
f = '/home/matheus_cascalho/Documents/Matheus Cascalho/MINDS/TimeSeries_Lab/sky.jpeg'

# %%
sky = Image.open(f)

# %%
sky
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x170 at 0x7F033A4A4610>

# %%
sky.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=297x170 at 0x7F0331E9E750>

# %%
img_data = np.asarray(sky.convert('L'))

# %%
img_data.shape
# Out:
# (170, 297)

# %%
img_data
# Out:
# array([[193, 193, 194, ..., 107, 107, 106],
#        [178, 185, 197, ..., 107, 107, 106],
#        [162, 172, 187, ..., 107, 107, 106],
#        ...,
#        [155, 156, 159, ..., 133, 133, 130],
#        [162, 160, 166, ..., 130, 138, 129],
#        [162, 160, 166, ..., 155, 154, 151]], dtype=uint8)

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.gca(projection='3d')

X = np.arange(0, 297, 1)
Y = np.arange(0, 170, 1)
X, Y = np.meshgrid(X, Y)
Z = img_data

# surf = ax2.plot_surface(X, Y, Z, cmap=cm.coolwarm, 
#                        linewidth=0, antialiased=False, alpha=0.7)

cset = ax.contour(X, Y, Z, zdir='x', offset=0, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=170, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='z', offset=100, cmap=cm.coolwarm)


ax.set_xlabel('X', size=20)
ax.set_ylabel('Y', size=20)
ax.set_zlabel('pixel', size=20)

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, 
                       linewidth=0, antialiased=False, alpha=0.7)
ax.set_xlabel('X', size=20)
ax.set_ylabel('Y', size=20)
ax.set_zlabel('pixel', size=20)


fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
